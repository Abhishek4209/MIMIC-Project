# %%
import numpy as np
import pandas as pd
import sys
import os 
import warnings
from datetime import datetime
from src.logger import logging
from src.exception import CustomException
warnings.filterwarnings("ignore")

# %%
## columns needed from icu stay csv
icu_keys = ['HADM_ID', 'ICUSTAY_ID', 'SUBJECT_ID', 'INTIME', 'OUTTIME', 'LOS']
icu_dates = ['INTIME', 'OUTTIME']

## columns needed from admissions csv
admissions_keys = ["HADM_ID", "ADMITTIME", "DEATHTIME", "ADMISSION_LOCATION",
                   "INSURANCE", "LANGUAGE", "RELIGION", "MARITAL_STATUS", "ETHNICITY",
                   "DIAGNOSIS","HAS_CHARTEVENTS_DATA"]
admissions_dates = ["ADMITTIME","DEATHTIME"]

## columns needed for patients csv
patients_keys = ['SUBJECT_ID', 'GENDER']

## columns needed from chartevents csv
chart_events_keys = ['ICUSTAY_ID', 'ITEMID', 'VALUENUM', 'CHARTTIME']
chart_events_dates = ['CHARTTIME']

# %%
logging.info('Load the Necessory Datasets...')
icu_stay_path=r'D:\FINALYEARPROJECTREC\data\ICUSTAYS.csv'
icu_stays = pd.read_csv(icu_stay_path, usecols=icu_keys, parse_dates=icu_dates)

# %%
admissions_path=r'D:\FINALYEARPROJECTREC\data\ADMISSIONS.csv'
admissions = pd.read_csv(admissions_path, usecols=admissions_keys, parse_dates=admissions_dates)

# %%
logging.info('left join icu_stays, admissions data tables, based on HADM_ID')
icu_adm = pd.merge(icu_stays, admissions, on="HADM_ID", how="left")
print("ICU Adm shape: ", icu_adm.shape)
# Out:
# ICU Adm shape:  (61532, 16)

# %%
icu_adm.head()
# Out:
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID              INTIME             OUTTIME  \
# 0         268   110404      280836 2198-02-14 23:27:00 2198-02-18 05:26:00
# 1         269   106296      206613 2170-11-05 11:05:00 2170-11-08 17:46:00
# 2         270   188028      220345 2128-06-24 15:05:00 2128-06-27 12:32:00
# 3         271   173727      249196 2120-08-07 23:12:00 2120-08-10 00:39:00
# 4         272   164716      210407 2186-12-25 21:08:00 2186-12-27 12:01:00
#
#       LOS         ADMITTIME           DEATHTIME         ADMISSION_LOCATION  \
# 0  3.2490  11-02-2198 13:40 2198-02-18 03:55:00       EMERGENCY ROOM ADMIT
# 1  3.2788  05-11-2170 11:04                 NaT       EMERGENCY ROOM ADMIT
# 2  2.8939  23-06-2128 18:26                 NaT  PHYS REFERRAL/NORMAL DELI
# 3  2.0600  07-08-2120 18:56                 NaT  TRANSFER FROM HOSP/EXTRAM
# 4  1.6202  25-12-2186 21:06                 NaT  TRANSFER FROM HOSP/EXTRAM
#
#   INSURANCE LANGUAGE           RELIGION MARITAL_STATUS  \
# 0  Medicare      NaN           CATHOLIC      SEPARATED
# 1  Medicaid      NaN       UNOBTAINABLE         SINGLE
# 2  Medicare      NaN  JEHOVAH'S WITNESS        MARRIED
# 3   Private     ENGL      NOT SPECIFIED        MARRIED
# 4  Medicare      NaN       UNOBTAINABLE        MARRIED
#
#                     ETHNICITY                                     DIAGNOSIS  \
# 0          HISPANIC OR LATINO                                       DYSPNEA
# 1                       WHITE                      SEPSIS;PILONIDAL ABSCESS
# 2       UNKNOWN/NOT SPECIFIED  CAROTID STENOSIS\CAROTID ANGIOGRAM AND STENT
# 3  PATIENT DECLINED TO ANSWER                        GALLSTONE PANCREATITIS
# 4                       WHITE                             PULMONARY EMBOLIS
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
logging.info('only keep rows that have chart events data')
icu_adm = icu_adm.loc[(icu_adm["HAS_CHARTEVENTS_DATA"] == 1)]
print(icu_adm.shape)
# Out:
# (61051, 16)

# %%
logging.info('show detailed dataframe info without abbreviation')
pd.set_option('display.max_columns', None)

# %%
logging.info(" read patients csv, and save into dataframe")
patients_path='D:\FINALYEARPROJECTREC\data\PATIENTS.csv'
patients = pd.read_csv(patients_path, usecols=patients_keys)
icu_adm = pd.merge(icu_adm, patients, on='SUBJECT_ID', how="left")

# %%
icu_adm.head()
# Out:
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID              INTIME             OUTTIME  \
# 0         268   110404      280836 2198-02-14 23:27:00 2198-02-18 05:26:00
# 1         269   106296      206613 2170-11-05 11:05:00 2170-11-08 17:46:00
# 2         270   188028      220345 2128-06-24 15:05:00 2128-06-27 12:32:00
# 3         271   173727      249196 2120-08-07 23:12:00 2120-08-10 00:39:00
# 4         272   164716      210407 2186-12-25 21:08:00 2186-12-27 12:01:00
#
#       LOS         ADMITTIME           DEATHTIME         ADMISSION_LOCATION  \
# 0  3.2490  11-02-2198 13:40 2198-02-18 03:55:00       EMERGENCY ROOM ADMIT
# 1  3.2788  05-11-2170 11:04                 NaT       EMERGENCY ROOM ADMIT
# 2  2.8939  23-06-2128 18:26                 NaT  PHYS REFERRAL/NORMAL DELI
# 3  2.0600  07-08-2120 18:56                 NaT  TRANSFER FROM HOSP/EXTRAM
# 4  1.6202  25-12-2186 21:06                 NaT  TRANSFER FROM HOSP/EXTRAM
#
#   INSURANCE LANGUAGE           RELIGION MARITAL_STATUS  \
# 0  Medicare      NaN           CATHOLIC      SEPARATED
# 1  Medicaid      NaN       UNOBTAINABLE         SINGLE
# 2  Medicare      NaN  JEHOVAH'S WITNESS        MARRIED
# 3   Private     ENGL      NOT SPECIFIED        MARRIED
# 4  Medicare      NaN       UNOBTAINABLE        MARRIED
#
#                     ETHNICITY                                     DIAGNOSIS  \
# 0          HISPANIC OR LATINO                                       DYSPNEA
# 1                       WHITE                      SEPSIS;PILONIDAL ABSCESS
# 2       UNKNOWN/NOT SPECIFIED  CAROTID STENOSIS\CAROTID ANGIOGRAM AND STENT
# 3  PATIENT DECLINED TO ANSWER                        GALLSTONE PANCREATITIS
# 4                       WHITE                             PULMONARY EMBOLIS
#
#    HAS_CHARTEVENTS_DATA GENDER
# 0                     1      F
# 1                     1      M
# 2                     1      M
# 3                     1      F
# 4                     1      M

# %%
logging.info("initialize chartevents column with empty array for each row")
icu_adm['CHARTEVENTS'] = np.empty((len(icu_adm), 0)).tolist()

logging.info("## set label to 1 if 1) death time exists 2) death time is between in time and out time of icu stay, else label 0")
icu_adm['LABEL'] = np.where(((pd.notna(icu_adm['DEATHTIME'])) & (icu_adm['INTIME'] <= icu_adm['DEATHTIME']) & (icu_adm['DEATHTIME'] <= icu_adm['OUTTIME'])), 1, 0)

logging.info("convert icu stay dataframe to dictionary format")
icu_adm_dict = icu_adm.to_dict('records')

# %%
icu_adm_dict
# Out:
# [{'SUBJECT_ID': 268,
#   'HADM_ID': 110404,
#   'ICUSTAY_ID': 280836,
#   'INTIME': Timestamp('2198-02-14 23:27:00'),
#   'OUTTIME': Timestamp('2198-02-18 05:26:00'),
#   'LOS': 3.249,
#   'ADMITTIME': '11-02-2198 13:40',
#   'DEATHTIME': Timestamp('2198-02-18 03:55:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'SEPARATED',
#   'ETHNICITY': 'HISPANIC OR LATINO',
#   'DIAGNOSIS': 'DYSPNEA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 1},
#  {'SUBJECT_ID': 269,
#   'HADM_ID': 106296,
#   'ICUSTAY_ID': 206613,
#   'INTIME': Timestamp('2170-11-05 11:05:00'),
#   'OUTTIME': Timestamp('2170-11-08 17:46:00'),
#   'LOS': 3.2788,
#   'ADMITTIME': '05-11-2170 11:04',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'SEPSIS;PILONIDAL ABSCESS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 270,
#   'HADM_ID': 188028,
#   'ICUSTAY_ID': 220345,
#   'INTIME': Timestamp('2128-06-24 15:05:00'),
#   'OUTTIME': Timestamp('2128-06-27 12:32:00'),
#   'LOS': 2.8939,
#   'ADMITTIME': '23-06-2128 18:26',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': "JEHOVAH'S WITNESS",
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'CAROTID STENOSIS\\CAROTID ANGIOGRAM AND STENT',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 271,
#   'HADM_ID': 173727,
#   'ICUSTAY_ID': 249196,
#   'INTIME': Timestamp('2120-08-07 23:12:00'),
#   'OUTTIME': Timestamp('2120-08-10 00:39:00'),
#   'LOS': 2.06,
#   'ADMITTIME': '07-08-2120 18:56',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'PATIENT DECLINED TO ANSWER',
#   'DIAGNOSIS': 'GALLSTONE PANCREATITIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 272,
#   'HADM_ID': 164716,
#   'ICUSTAY_ID': 210407,
#   'INTIME': Timestamp('2186-12-25 21:08:00'),
#   'OUTTIME': Timestamp('2186-12-27 12:01:00'),
#   'LOS': 1.6202,
#   'ADMITTIME': '25-12-2186 21:06',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'PULMONARY EMBOLIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 273,
#   'HADM_ID': 158689,
#   'ICUSTAY_ID': 241507,
#   'INTIME': Timestamp('2141-04-19 06:12:00'),
#   'OUTTIME': Timestamp('2141-04-20 17:52:00'),
#   'LOS': 1.4862,
#   'ADMITTIME': '19-04-2141 06:11',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'OTHER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'POLYSUBSTANCE OVERDOSE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 274,
#   'HADM_ID': 130546,
#   'ICUSTAY_ID': 254851,
#   'INTIME': Timestamp('2114-06-28 22:28:00'),
#   'OUTTIME': Timestamp('2114-07-07 18:01:00'),
#   'LOS': 8.8143,
#   'ADMITTIME': '28-06-2114 22:16',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'SUBARACHNOID HEMORRHAGE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 275,
#   'HADM_ID': 129886,
#   'ICUSTAY_ID': 219649,
#   'INTIME': Timestamp('2170-10-07 11:28:00'),
#   'OUTTIME': Timestamp('2170-10-14 14:38:00'),
#   'LOS': 7.1314,
#   'ADMITTIME': '06-10-2170 03:09',
#   'DEATHTIME': Timestamp('2170-10-19 15:35:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'RUSS',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'UROSEPSIS-CHANGE IN MENTAL STATUS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 276,
#   'HADM_ID': 135156,
#   'ICUSTAY_ID': 206327,
#   'INTIME': Timestamp('2147-11-20 09:02:00'),
#   'OUTTIME': Timestamp('2147-11-21 17:08:00'),
#   'LOS': 1.3378,
#   'ADMITTIME': '19-11-2147 16:53',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'GASTROINTESTINAL BLEED',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 277,
#   'HADM_ID': 171601,
#   'ICUSTAY_ID': 272866,
#   'INTIME': Timestamp('2132-10-21 21:11:00'),
#   'OUTTIME': Timestamp('2132-10-22 14:44:00'),
#   'LOS': 0.7313,
#   'ADMITTIME': '21-10-2132 21:09',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 279,
#   'HADM_ID': 192224,
#   'ICUSTAY_ID': 204407,
#   'INTIME': Timestamp('2164-06-14 21:18:00'),
#   'OUTTIME': Timestamp('2164-06-18 22:53:00'),
#   'LOS': 4.0658,
#   'ADMITTIME': '13-06-2164 19:19',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ENDOSCOPIC RETROGRADE CHOLANGIOPANCREATOGRAPHY;SPHINCTEROTOMY',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 280,
#   'HADM_ID': 123506,
#   'ICUSTAY_ID': 247496,
#   'INTIME': Timestamp('2155-12-08 18:22:00'),
#   'OUTTIME': Timestamp('2155-12-22 17:10:00'),
#   'LOS': 13.9504,
#   'ADMITTIME': '08-12-2155 18:11',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 281,
#   'HADM_ID': 111199,
#   'ICUSTAY_ID': 257572,
#   'INTIME': Timestamp('2101-10-18 04:45:00'),
#   'OUTTIME': Timestamp('2101-10-25 22:29:00'),
#   'LOS': 7.7389,
#   'ADMITTIME': '18-10-2101 04:42',
#   'DEATHTIME': Timestamp('2101-10-25 19:10:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Government',
#   'LANGUAGE': nan,
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'PNEUMONIA,HYPONATREMIA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 1},
#  {'SUBJECT_ID': 282,
#   'HADM_ID': 119013,
#   'ICUSTAY_ID': 293262,
#   'INTIME': Timestamp('2175-02-02 17:01:00'),
#   'OUTTIME': Timestamp('2175-02-03 13:27:00'),
#   'LOS': 0.8519,
#   'ADMITTIME': '01-02-2175 17:47',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'RIGHT HIP FRACTURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 283,
#   'HADM_ID': 109185,
#   'ICUSTAY_ID': 231490,
#   'INTIME': Timestamp('2166-08-12 22:03:00'),
#   'OUTTIME': Timestamp('2166-09-12 14:41:00'),
#   'LOS': 30.6932,
#   'ADMITTIME': '12-08-2166 22:02',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': nan,
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'PNEUMONIA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 283,
#   'HADM_ID': 144156,
#   'ICUSTAY_ID': 280531,
#   'INTIME': Timestamp('2166-10-02 15:38:00'),
#   'OUTTIME': Timestamp('2166-10-07 13:22:00'),
#   'LOS': 4.9051,
#   'ADMITTIME': '02-10-2166 15:36',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': nan,
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CHANGE IN MENTAL STATUS;SEIZURES',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 284,
#   'HADM_ID': 112354,
#   'ICUSTAY_ID': 223593,
#   'INTIME': Timestamp('2149-11-29 15:39:00'),
#   'OUTTIME': Timestamp('2149-11-30 17:18:00'),
#   'LOS': 1.0685,
#   'ADMITTIME': '29-11-2149 15:37',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'GASTROINTESTINAL BLEED',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 285,
#   'HADM_ID': 165312,
#   'ICUSTAY_ID': 238023,
#   'INTIME': Timestamp('2152-09-21 22:48:00'),
#   'OUTTIME': Timestamp('2152-10-20 15:19:00'),
#   'LOS': 28.688,
#   'ADMITTIME': '21-09-2152 22:47',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'SPAN',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'HISPANIC OR LATINO',
#   'DIAGNOSIS': 'SPINAL INJURY',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 286,
#   'HADM_ID': 106909,
#   'ICUSTAY_ID': 260225,
#   'INTIME': Timestamp('2175-12-31 22:57:00'),
#   'OUTTIME': Timestamp('2176-02-24 19:16:00'),
#   'LOS': 54.8469,
#   'ADMITTIME': '31-12-2175 22:56',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ASTHMA, COPD EXACERBATION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 287,
#   'HADM_ID': 174293,
#   'ICUSTAY_ID': 270957,
#   'INTIME': Timestamp('2167-05-22 16:13:00'),
#   'OUTTIME': Timestamp('2167-05-25 16:04:00'),
#   'LOS': 2.994,
#   'ADMITTIME': '22-05-2167 07:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ADENO CANCER ETHMOID SINUS /SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 287,
#   'HADM_ID': 175954,
#   'ICUSTAY_ID': 245343,
#   'INTIME': Timestamp('2167-05-31 13:23:00'),
#   'OUTTIME': Timestamp('2167-06-03 17:47:00'),
#   'LOS': 3.183,
#   'ADMITTIME': '31-05-2167 13:22',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'FEVER,ALTERED MENTAL STATUS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 288,
#   'HADM_ID': 110921,
#   'ICUSTAY_ID': 216651,
#   'INTIME': Timestamp('2191-05-19 12:47:00'),
#   'OUTTIME': Timestamp('2191-05-27 15:15:00'),
#   'LOS': 8.1027,
#   'ADMITTIME': '19-05-2191 12:41',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 290,
#   'HADM_ID': 138303,
#   'ICUSTAY_ID': 278519,
#   'INTIME': Timestamp('2179-01-26 19:27:00'),
#   'OUTTIME': Timestamp('2179-01-31 11:37:00'),
#   'LOS': 4.6738,
#   'ADMITTIME': '26-01-2179 07:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'ESOPHAGEAL DYSPLASIA/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 291,
#   'HADM_ID': 113649,
#   'ICUSTAY_ID': 256641,
#   'INTIME': Timestamp('2102-04-08 23:05:00'),
#   'OUTTIME': Timestamp('2102-04-09 11:20:00'),
#   'LOS': 0.5102,
#   'ADMITTIME': '08-04-2102 22:26',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CHEST PAIN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 291,
#   'HADM_ID': 125726,
#   'ICUSTAY_ID': 275109,
#   'INTIME': Timestamp('2106-04-17 12:26:00'),
#   'OUTTIME': Timestamp('2106-04-18 22:05:00'),
#   'LOS': 1.4023,
#   'ADMITTIME': '17-04-2106 12:24',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ACUTE CORONARY SYNDROME',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 291,
#   'HADM_ID': 126219,
#   'ICUSTAY_ID': 246725,
#   'INTIME': Timestamp('2107-09-13 22:43:00'),
#   'OUTTIME': Timestamp('2107-09-14 18:34:00'),
#   'LOS': 0.8276,
#   'ADMITTIME': '13-09-2107 22:41',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ALTERED MENTAL STATUS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 292,
#   'HADM_ID': 179726,
#   'ICUSTAY_ID': 222505,
#   'INTIME': Timestamp('2103-09-27 18:29:00'),
#   'OUTTIME': Timestamp('2103-09-28 15:44:00'),
#   'LOS': 0.8854,
#   'ADMITTIME': '27-09-2103 18:28',
#   'DEATHTIME': Timestamp('2103-09-28 15:44:00'),
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'CIRRHOSIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 1},
#  {'SUBJECT_ID': 293,
#   'HADM_ID': 125963,
#   'ICUSTAY_ID': 263651,
#   'INTIME': Timestamp('2125-02-09 10:35:00'),
#   'OUTTIME': Timestamp('2125-02-10 11:57:00'),
#   'LOS': 1.057,
#   'ADMITTIME': '09-02-2125 07:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'JEWISH',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ASD\\REPAIR ATRIAL-SEPTAL DEFECT/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 294,
#   'HADM_ID': 152578,
#   'ICUSTAY_ID': 222074,
#   'INTIME': Timestamp('2118-01-17 21:45:00'),
#   'OUTTIME': Timestamp('2118-01-20 11:12:00'),
#   'LOS': 2.5609,
#   'ADMITTIME': '17-01-2118 21:44',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'OTHER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'S/P MI;ISCHEMIC LEFT LEG',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 295,
#   'HADM_ID': 192988,
#   'ICUSTAY_ID': 274998,
#   'INTIME': Timestamp('2176-03-06 18:55:00'),
#   'OUTTIME': Timestamp('2176-03-07 16:39:00'),
#   'LOS': 0.9057,
#   'ADMITTIME': '06-03-2176 12:30',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ANEURYSM/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 296,
#   'HADM_ID': 159503,
#   'ICUSTAY_ID': 273199,
#   'INTIME': Timestamp('2191-03-01 21:31:00'),
#   'OUTTIME': Timestamp('2191-03-02 18:12:00'),
#   'LOS': 0.8618,
#   'ADMITTIME': '01-03-2191 21:31',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': nan,
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'CHEST PAIN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 297,
#   'HADM_ID': 107224,
#   'ICUSTAY_ID': 203620,
#   'INTIME': Timestamp('2135-10-05 14:55:00'),
#   'OUTTIME': Timestamp('2135-10-05 17:05:00'),
#   'LOS': 0.0904,
#   'ADMITTIME': '05-10-2135 13:05',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 298,
#   'HADM_ID': 119446,
#   'ICUSTAY_ID': 225523,
#   'INTIME': Timestamp('2140-08-07 00:33:00'),
#   'OUTTIME': Timestamp('2140-08-09 06:46:00'),
#   'LOS': 2.259,
#   'ADMITTIME': '07-08-2140 00:33',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'RUSS',
#   'RELIGION': 'UNITARIAN-UNIVERSALIST',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'LOWER GI BLEED',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 299,
#   'HADM_ID': 195143,
#   'ICUSTAY_ID': 204434,
#   'INTIME': Timestamp('2176-07-01 19:09:00'),
#   'OUTTIME': Timestamp('2176-07-01 20:21:00'),
#   'LOS': 0.0501,
#   'ADMITTIME': '01-07-2176 19:07',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Government',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'ASIAN',
#   'DIAGNOSIS': 'HYPERBILIRUBINEMIA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 300,
#   'HADM_ID': 142952,
#   'ICUSTAY_ID': 208862,
#   'INTIME': Timestamp('2131-10-17 00:14:00'),
#   'OUTTIME': Timestamp('2131-10-17 05:34:00'),
#   'LOS': 0.222,
#   'ADMITTIME': '16-10-2131 21:33',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 301,
#   'HADM_ID': 160332,
#   'ICUSTAY_ID': 288401,
#   'INTIME': Timestamp('2189-11-11 12:12:00'),
#   'OUTTIME': Timestamp('2189-11-13 22:11:00'),
#   'LOS': 2.4159,
#   'ADMITTIME': '10-11-2189 16:39',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'RUSS',
#   'RELIGION': 'JEWISH',
#   'MARITAL_STATUS': 'DIVORCED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'DEHYDRATION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 302,
#   'HADM_ID': 191028,
#   'ICUSTAY_ID': 249750,
#   'INTIME': Timestamp('2133-03-29 02:34:00'),
#   'OUTTIME': Timestamp('2133-03-30 22:50:00'),
#   'LOS': 1.8447,
#   'ADMITTIME': '29-03-2133 02:33',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'OTHER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ACUTE MYOCARDIAL INFARCTION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 303,
#   'HADM_ID': 175574,
#   'ICUSTAY_ID': 271668,
#   'INTIME': Timestamp('2160-03-17 18:58:00'),
#   'OUTTIME': Timestamp('2160-03-18 21:10:00'),
#   'LOS': 1.0917,
#   'ADMITTIME': '17-03-2160 18:37',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'MULTI-TRAUMA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 303,
#   'HADM_ID': 103013,
#   'ICUSTAY_ID': 261797,
#   'INTIME': Timestamp('2163-03-29 23:05:00'),
#   'OUTTIME': Timestamp('2163-04-01 17:41:00'),
#   'LOS': 2.7756,
#   'ADMITTIME': '29-03-2163 23:04',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'TYLENOL,OVERDOSE;LIVER FAILURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 304,
#   'HADM_ID': 177469,
#   'ICUSTAY_ID': 295659,
#   'INTIME': Timestamp('2141-05-18 17:22:00'),
#   'OUTTIME': Timestamp('2141-05-19 05:40:00'),
#   'LOS': 0.5129,
#   'ADMITTIME': '18-05-2141 17:21',
#   'DEATHTIME': Timestamp('2141-05-19 01:45:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': 'CAPE',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'ICH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 1},
#  {'SUBJECT_ID': 305,
#   'HADM_ID': 133059,
#   'ICUSTAY_ID': 232719,
#   'INTIME': Timestamp('2125-04-27 18:47:00'),
#   'OUTTIME': Timestamp('2125-05-01 16:50:00'),
#   'LOS': 3.9185,
#   'ADMITTIME': '26-04-2125 11:45',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'PORT',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CORONARY ARTERY DISEASE\\CORONARY ARTERY BYPASS GRAFT',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 305,
#   'HADM_ID': 108015,
#   'ICUSTAY_ID': 297009,
#   'INTIME': Timestamp('2126-01-02 11:28:00'),
#   'OUTTIME': Timestamp('2126-01-07 10:07:00'),
#   'LOS': 4.9438,
#   'ADMITTIME': '31-12-2125 18:40',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'PORT',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NON-ST SEGMENT ELEVATION MYOCARDIAL INFARCTION\\CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 305,
#   'HADM_ID': 122211,
#   'ICUSTAY_ID': 224571,
#   'INTIME': Timestamp('2127-06-19 23:50:00'),
#   'OUTTIME': Timestamp('2127-06-20 18:51:00'),
#   'LOS': 0.7925,
#   'ADMITTIME': '19-06-2127 23:49',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'PORT',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CONGESTIVE HEART FAILURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 305,
#   'HADM_ID': 122211,
#   'ICUSTAY_ID': 232248,
#   'INTIME': Timestamp('2127-07-03 20:02:00'),
#   'OUTTIME': Timestamp('2127-07-09 15:31:00'),
#   'LOS': 5.8118,
#   'ADMITTIME': '19-06-2127 23:49',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'PORT',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CONGESTIVE HEART FAILURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 305,
#   'HADM_ID': 194340,
#   'ICUSTAY_ID': 217232,
#   'INTIME': Timestamp('2129-09-03 12:31:00'),
#   'OUTTIME': Timestamp('2129-09-05 23:00:00'),
#   'LOS': 2.437,
#   'ADMITTIME': '20-08-2129 18:03',
#   'DEATHTIME': Timestamp('2129-09-07 17:55:00'),
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'PORT',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'HEART FAILURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 306,
#   'HADM_ID': 167129,
#   'ICUSTAY_ID': 291141,
#   'INTIME': Timestamp('2199-09-15 19:59:00'),
#   'OUTTIME': Timestamp('2199-09-18 14:45:00'),
#   'LOS': 2.7815,
#   'ADMITTIME': '15-09-2199 19:59',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Government',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'SUBDURAL HEMATOMA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 307,
#   'HADM_ID': 132807,
#   'ICUSTAY_ID': 265862,
#   'INTIME': Timestamp('2162-11-27 22:46:00'),
#   'OUTTIME': Timestamp('2162-12-03 20:41:00'),
#   'LOS': 5.9133,
#   'ADMITTIME': '24-11-2162 20:49',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'LEFT RENAL TUMOR;LEFT RENAL ARTERY STENOSIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 307,
#   'HADM_ID': 161712,
#   'ICUSTAY_ID': 248439,
#   'INTIME': Timestamp('2164-01-02 14:20:00'),
#   'OUTTIME': Timestamp('2164-01-03 15:48:00'),
#   'LOS': 1.0615,
#   'ADMITTIME': '27-12-2163 04:29',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'SHORTNESS OF BREATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 308,
#   'HADM_ID': 166606,
#   'ICUSTAY_ID': 283522,
#   'INTIME': Timestamp('2135-09-04 12:54:00'),
#   'OUTTIME': Timestamp('2135-09-30 16:35:00'),
#   'LOS': 26.1535,
#   'ADMITTIME': '02-09-2135 23:07',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'DILANTIN TOXICITY-MENTAL STATUS CHANGES',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 309,
#   'HADM_ID': 162308,
#   'ICUSTAY_ID': 211035,
#   'INTIME': Timestamp('2160-06-04 09:45:00'),
#   'OUTTIME': Timestamp('2160-06-05 19:03:00'),
#   'LOS': 1.3873,
#   'ADMITTIME': '04-06-2160 09:45',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CHEST PAIN;CORONARY ARTERY DISEASE\\CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 310,
#   'HADM_ID': 142159,
#   'ICUSTAY_ID': 269885,
#   'INTIME': Timestamp('2139-05-06 23:58:00'),
#   'OUTTIME': Timestamp('2139-05-08 15:29:00'),
#   'LOS': 1.6464,
#   'ADMITTIME': '06-05-2139 13:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CHIARI I MALFORMATION/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 312,
#   'HADM_ID': 166526,
#   'ICUSTAY_ID': 290299,
#   'INTIME': Timestamp('2130-06-14 13:17:00'),
#   'OUTTIME': Timestamp('2130-06-14 14:10:00'),
#   'LOS': 0.0371,
#   'ADMITTIME': '14-06-2130 09:43',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 313,
#   'HADM_ID': 199765,
#   'ICUSTAY_ID': 261824,
#   'INTIME': Timestamp('2139-07-26 16:46:00'),
#   'OUTTIME': Timestamp('2139-07-31 21:01:00'),
#   'LOS': 5.1771,
#   'ADMITTIME': '26-07-2139 16:43',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'C7 FRACTURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 314,
#   'HADM_ID': 155540,
#   'ICUSTAY_ID': 261257,
#   'INTIME': Timestamp('2181-09-18 01:11:00'),
#   'OUTTIME': Timestamp('2181-09-22 21:15:00'),
#   'LOS': 4.8358,
#   'ADMITTIME': '18-09-2181 01:11',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': nan,
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'HYPERTENSION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 315,
#   'HADM_ID': 152144,
#   'ICUSTAY_ID': 266988,
#   'INTIME': Timestamp('2177-04-29 08:04:00'),
#   'OUTTIME': Timestamp('2177-05-04 16:12:00'),
#   'LOS': 5.3387,
#   'ADMITTIME': '24-04-2177 18:01',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'OTHER',
#   'DIAGNOSIS': 'CORONARY ARTERY DISEASE\\CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 316,
#   'HADM_ID': 110748,
#   'ICUSTAY_ID': 276876,
#   'INTIME': Timestamp('2134-11-03 16:56:00'),
#   'OUTTIME': Timestamp('2134-11-05 23:16:00'),
#   'LOS': 2.2638,
#   'ADMITTIME': '03-11-2134 15:40',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'HISPANIC OR LATINO',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 317,
#   'HADM_ID': 173307,
#   'ICUSTAY_ID': 266184,
#   'INTIME': Timestamp('2113-10-24 12:16:00'),
#   'OUTTIME': Timestamp('2113-10-27 14:57:00'),
#   'LOS': 3.1118,
#   'ADMITTIME': '24-10-2113 12:16',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'DIVORCED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'SEVERE OBSTRUCTIVE HYPERTROPHIC CARDIOMYOPATHY\\SEPTAL ETHANOL ABLATION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 318,
#   'HADM_ID': 193264,
#   'ICUSTAY_ID': 225173,
#   'INTIME': Timestamp('2129-06-07 08:50:00'),
#   'OUTTIME': Timestamp('2129-06-13 10:45:00'),
#   'LOS': 6.0799,
#   'ADMITTIME': '07-06-2129 08:49',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': nan,
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'MYOCARDIAL INFARCTION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 319,
#   'HADM_ID': 124954,
#   'ICUSTAY_ID': 281554,
#   'INTIME': Timestamp('2156-08-12 14:01:00'),
#   'OUTTIME': Timestamp('2156-08-14 22:21:00'),
#   'LOS': 2.3471,
#   'ADMITTIME': '12-08-2156 14:01',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'BRIGHT RED BLOOD PER RECTUM',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 320,
#   'HADM_ID': 172849,
#   'ICUSTAY_ID': 221205,
#   'INTIME': Timestamp('2145-10-09 09:50:00'),
#   'OUTTIME': Timestamp('2145-10-09 20:39:00'),
#   'LOS': 0.4507,
#   'ADMITTIME': '09-10-2145 09:49',
#   'DEATHTIME': Timestamp('2145-10-09 14:28:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'UNSTABLE ANGINA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 1},
#  {'SUBJECT_ID': 321,
#   'HADM_ID': 199004,
#   'ICUSTAY_ID': 240147,
#   'INTIME': Timestamp('2189-06-12 22:26:00'),
#   'OUTTIME': Timestamp('2189-06-14 23:11:00'),
#   'LOS': 2.0313,
#   'ADMITTIME': '11-06-2189 11:36',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'UNSTABLE ANGINA\\CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 321,
#   'HADM_ID': 192097,
#   'ICUSTAY_ID': 254444,
#   'INTIME': Timestamp('2190-03-03 19:52:00'),
#   'OUTTIME': Timestamp('2190-03-05 16:05:00'),
#   'LOS': 1.8421,
#   'ADMITTIME': '01-03-2190 07:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'LEFT HIP FRACTURE/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 322,
#   'HADM_ID': 177634,
#   'ICUSTAY_ID': 217128,
#   'INTIME': Timestamp('2135-05-02 14:46:00'),
#   'OUTTIME': Timestamp('2135-05-04 20:23:00'),
#   'LOS': 2.2337,
#   'ADMITTIME': '02-05-2135 07:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'OTHER',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'AORTIC STENOSIS\\AORTIC VALVE REPLACEMENT /SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 323,
#   'HADM_ID': 106158,
#   'ICUSTAY_ID': 249949,
#   'INTIME': Timestamp('2116-05-04 05:30:00'),
#   'OUTTIME': Timestamp('2116-05-08 15:52:00'),
#   'LOS': 4.4319,
#   'ADMITTIME': '03-05-2116 23:07',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CONGESTIVE HEART FAILURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 323,
#   'HADM_ID': 128132,
#   'ICUSTAY_ID': 206073,
#   'INTIME': Timestamp('2119-09-21 20:34:00'),
#   'OUTTIME': Timestamp('2119-10-03 20:34:00'),
#   'LOS': 11.9999,
#   'ADMITTIME': '21-09-2119 20:34',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'HYPOTENSION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 323,
#   'HADM_ID': 143334,
#   'ICUSTAY_ID': 264375,
#   'INTIME': Timestamp('2120-01-11 15:48:00'),
#   'OUTTIME': Timestamp('2120-01-14 16:24:00'),
#   'LOS': 3.0252,
#   'ADMITTIME': '11-01-2120 15:46',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'SEPSIS;TELEMETRY',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 324,
#   'HADM_ID': 146127,
#   'ICUSTAY_ID': 285067,
#   'INTIME': Timestamp('2199-10-16 01:39:00'),
#   'OUTTIME': Timestamp('2199-10-16 17:19:00'),
#   'LOS': 0.6528,
#   'ADMITTIME': '16-10-2199 01:11',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'JEWISH',
#   'MARITAL_STATUS': 'DIVORCED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'S/P FALL',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 325,
#   'HADM_ID': 155989,
#   'ICUSTAY_ID': 221000,
#   'INTIME': Timestamp('2190-01-05 20:28:00'),
#   'OUTTIME': Timestamp('2190-01-08 18:08:00'),
#   'LOS': 2.9029,
#   'ADMITTIME': '05-01-2190 07:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'METASTATIC PANCREATIC CA/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 326,
#   'HADM_ID': 188926,
#   'ICUSTAY_ID': 281585,
#   'INTIME': Timestamp('2118-11-01 21:46:00'),
#   'OUTTIME': Timestamp('2118-11-05 14:16:00'),
#   'LOS': 3.6877,
#   'ADMITTIME': '01-11-2118 21:46',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Government',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'MENTAL STATUS CHANGES;TELEMETRY',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 327,
#   'HADM_ID': 146750,
#   'ICUSTAY_ID': 272596,
#   'INTIME': Timestamp('2194-04-28 18:27:00'),
#   'OUTTIME': Timestamp('2194-04-29 15:53:00'),
#   'LOS': 0.8932,
#   'ADMITTIME': '28-04-2194 09:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'MALUNION FRACTURE RIGHT WRIST/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 328,
#   'HADM_ID': 146586,
#   'ICUSTAY_ID': 294224,
#   'INTIME': Timestamp('2149-10-31 14:45:00'),
#   'OUTTIME': Timestamp('2149-11-05 14:56:00'),
#   'LOS': 5.0078,
#   'ADMITTIME': '31-10-2149 14:44',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'SPAN',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'HISPANIC OR LATINO',
#   'DIAGNOSIS': 'ACUTE MYOCARDIAL INFARCTION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 328,
#   'HADM_ID': 121438,
#   'ICUSTAY_ID': 211849,
#   'INTIME': Timestamp('2149-12-19 02:35:00'),
#   'OUTTIME': Timestamp('2149-12-21 13:16:00'),
#   'LOS': 2.4448,
#   'ADMITTIME': '19-12-2149 02:34',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'SPAN',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'HISPANIC OR LATINO',
#   'DIAGNOSIS': 'ACUTE MYOCARDIAL INFARCTION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 329,
#   'HADM_ID': 172132,
#   'ICUSTAY_ID': 217001,
#   'INTIME': Timestamp('2154-04-05 16:36:00'),
#   'OUTTIME': Timestamp('2154-04-08 18:14:00'),
#   'LOS': 3.068,
#   'ADMITTIME': '05-04-2154 16:35',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'BUDDHIST',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'ASIAN - VIETNAMESE',
#   'DIAGNOSIS': 'FEVER',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 330,
#   'HADM_ID': 197569,
#   'ICUSTAY_ID': 297996,
#   'INTIME': Timestamp('2133-02-27 17:16:00'),
#   'OUTTIME': Timestamp('2133-03-09 16:57:00'),
#   'LOS': 9.9866,
#   'ADMITTIME': '27-02-2133 12:30',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'LEFT CAROTID STENOSIS/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 331,
#   'HADM_ID': 159710,
#   'ICUSTAY_ID': 296409,
#   'INTIME': Timestamp('2166-04-16 03:27:00'),
#   'OUTTIME': Timestamp('2166-04-16 20:10:00'),
#   'LOS': 0.6965,
#   'ADMITTIME': '16-04-2166 03:23',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 332,
#   'HADM_ID': 128404,
#   'ICUSTAY_ID': 287595,
#   'INTIME': Timestamp('2178-02-16 01:56:00'),
#   'OUTTIME': Timestamp('2178-02-16 09:00:00'),
#   'LOS': 0.2939,
#   'ADMITTIME': '16-02-2178 01:12',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 333,
#   'HADM_ID': 160548,
#   'ICUSTAY_ID': 243350,
#   'INTIME': Timestamp('2137-09-29 06:03:00'),
#   'OUTTIME': Timestamp('2137-10-01 14:15:00'),
#   'LOS': 2.3419,
#   'ADMITTIME': '29-09-2137 04:45',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'INSTEMI\\CARDIAC CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 334,
#   'HADM_ID': 104852,
#   'ICUSTAY_ID': 214236,
#   'INTIME': Timestamp('2136-01-16 10:56:00'),
#   'OUTTIME': Timestamp('2136-01-30 18:18:00'),
#   'LOS': 14.3065,
#   'ADMITTIME': '16-01-2136 10:46',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 335,
#   'HADM_ID': 110777,
#   'ICUSTAY_ID': 278926,
#   'INTIME': Timestamp('2195-03-24 15:26:00'),
#   'OUTTIME': Timestamp('2195-03-26 14:44:00'),
#   'LOS': 1.9713,
#   'ADMITTIME': '18-03-2195 11:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'ANEURSYM/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 336,
#   'HADM_ID': 166434,
#   'ICUSTAY_ID': 271066,
#   'INTIME': Timestamp('2111-09-10 02:43:00'),
#   'OUTTIME': Timestamp('2111-09-10 03:46:00'),
#   'LOS': 0.0433,
#   'ADMITTIME': '10-09-2111 00:54',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 337,
#   'HADM_ID': 181797,
#   'ICUSTAY_ID': 256167,
#   'INTIME': Timestamp('2126-10-20 06:00:00'),
#   'OUTTIME': Timestamp('2126-10-20 09:44:00'),
#   'LOS': 0.1559,
#   'ADMITTIME': '20-10-2126 05:58',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 338,
#   'HADM_ID': 194592,
#   'ICUSTAY_ID': 217990,
#   'INTIME': Timestamp('2135-10-27 19:13:00'),
#   'OUTTIME': Timestamp('2135-10-28 22:40:00'),
#   'LOS': 1.1439,
#   'ADMITTIME': '26-10-2135 23:21',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'KIDNEY THROMBOEMBOLISM',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 339,
#   'HADM_ID': 112625,
#   'ICUSTAY_ID': 221278,
#   'INTIME': Timestamp('2187-04-20 23:10:00'),
#   'OUTTIME': Timestamp('2187-05-22 16:01:00'),
#   'LOS': 31.7018,
#   'ADMITTIME': '20-04-2187 23:10',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': '*MAN',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'PANCREATITIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 339,
#   'HADM_ID': 183291,
#   'ICUSTAY_ID': 267031,
#   'INTIME': Timestamp('2187-08-07 12:45:00'),
#   'OUTTIME': Timestamp('2187-08-09 01:07:00'),
#   'LOS': 1.5153,
#   'ADMITTIME': '07-08-2187 07:15',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': '*MAN',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'ACUTE PANCREATITIS/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 339,
#   'HADM_ID': 107660,
#   'ICUSTAY_ID': 255582,
#   'INTIME': Timestamp('2188-04-10 07:08:00'),
#   'OUTTIME': Timestamp('2188-04-15 14:22:00'),
#   'LOS': 5.301,
#   'ADMITTIME': '01-04-2188 07:11',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': '*MAN',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'PANCREATITIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 340,
#   'HADM_ID': 139131,
#   'ICUSTAY_ID': 279117,
#   'INTIME': Timestamp('2182-01-19 18:14:00'),
#   'OUTTIME': Timestamp('2182-02-05 20:35:00'),
#   'LOS': 17.0983,
#   'ADMITTIME': '19-01-2182 18:13',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'DIVORCED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'HEAD BLEED',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 341,
#   'HADM_ID': 149955,
#   'ICUSTAY_ID': 271894,
#   'INTIME': Timestamp('2178-10-03 18:23:00'),
#   'OUTTIME': Timestamp('2178-10-03 21:04:00'),
#   'LOS': 0.1119,
#   'ADMITTIME': '03-10-2178 18:17',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 342,
#   'HADM_ID': 193432,
#   'ICUSTAY_ID': 203303,
#   'INTIME': Timestamp('2171-08-20 11:28:00'),
#   'OUTTIME': Timestamp('2171-08-22 17:20:00'),
#   'LOS': 2.2438,
#   'ADMITTIME': '20-08-2171 11:26',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'ENCEPHALOPATHY;TELEMETRY',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 344,
#   'HADM_ID': 176203,
#   'ICUSTAY_ID': 238865,
#   'INTIME': Timestamp('2154-11-12 20:54:00'),
#   'OUTTIME': Timestamp('2154-11-16 08:30:00'),
#   'LOS': 3.4836,
#   'ADMITTIME': '12-11-2154 20:53',
#   'DEATHTIME': Timestamp('2154-11-16 05:45:00'),
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
# ...
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 448,
#   'HADM_ID': 125279,
#   'ICUSTAY_ID': 218121,
#   'INTIME': Timestamp('2136-05-01 21:04:00'),
#   'OUTTIME': Timestamp('2136-05-04 15:31:00'),
#   'LOS': 2.7687,
#   'ADMITTIME': '25-04-2136 19:49',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'VERTEBRAL ARTERY STENOSIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 450,
#   'HADM_ID': 105452,
#   'ICUSTAY_ID': 224092,
#   'INTIME': Timestamp('2155-05-18 23:29:00'),
#   'OUTTIME': Timestamp('2155-05-19 15:47:00'),
#   'LOS': 0.6793,
#   'ADMITTIME': '10-05-2155 18:12',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'HISPANIC OR LATINO',
#   'DIAGNOSIS': 'SEPSIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 450,
#   'HADM_ID': 182829,
#   'ICUSTAY_ID': 211362,
#   'INTIME': Timestamp('2155-07-24 13:55:00'),
#   'OUTTIME': Timestamp('2155-08-02 23:33:00'),
#   'LOS': 9.4012,
#   'ADMITTIME': '24-07-2155 13:28',
#   'DEATHTIME': Timestamp('2155-08-04 07:25:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'HISPANIC OR LATINO',
#   'DIAGNOSIS': 'HYPOXIA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 451,
#   'HADM_ID': 132072,
#   'ICUSTAY_ID': 207788,
#   'INTIME': Timestamp('2178-08-08 02:59:00'),
#   'OUTTIME': Timestamp('2178-08-08 07:48:00'),
#   'LOS': 0.2005,
#   'ADMITTIME': '08-08-2178 02:54',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'MUSLIM',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'ASIAN',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 452,
#   'HADM_ID': 131499,
#   'ICUSTAY_ID': 260015,
#   'INTIME': Timestamp('2110-05-13 16:59:00'),
#   'OUTTIME': Timestamp('2110-05-17 18:37:00'),
#   'LOS': 4.068,
#   'ADMITTIME': '13-05-2110 00:45',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'END STAGE LIVER DISEASE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 452,
#   'HADM_ID': 177171,
#   'ICUSTAY_ID': 296795,
#   'INTIME': Timestamp('2110-07-26 04:19:00'),
#   'OUTTIME': Timestamp('2110-08-03 16:29:00'),
#   'LOS': 8.5069,
#   'ADMITTIME': '22-07-2110 22:36',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM OTHER HEALT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ELEVATED CREATNINE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 452,
#   'HADM_ID': 177171,
#   'ICUSTAY_ID': 239694,
#   'INTIME': Timestamp('2110-08-07 10:39:00'),
#   'OUTTIME': Timestamp('2110-08-10 15:57:00'),
#   'LOS': 3.221,
#   'ADMITTIME': '22-07-2110 22:36',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM OTHER HEALT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ELEVATED CREATNINE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 453,
#   'HADM_ID': 187961,
#   'ICUSTAY_ID': 207460,
#   'INTIME': Timestamp('2156-04-22 08:46:00'),
#   'OUTTIME': Timestamp('2156-04-26 19:18:00'),
#   'LOS': 4.4391,
#   'ADMITTIME': '22-04-2156 08:44',
#   'DEATHTIME': Timestamp('2156-05-05 02:04:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'JEWISH',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'FEBRILE SYNDROME',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 454,
#   'HADM_ID': 182153,
#   'ICUSTAY_ID': 236699,
#   'INTIME': Timestamp('2127-06-26 19:19:00'),
#   'OUTTIME': Timestamp('2127-06-29 15:02:00'),
#   'LOS': 2.8214,
#   'ADMITTIME': '26-06-2127 19:17',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'CEREBROVASCULAR ACCIDENT',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 455,
#   'HADM_ID': 111582,
#   'ICUSTAY_ID': 216013,
#   'INTIME': Timestamp('2110-11-16 15:38:00'),
#   'OUTTIME': Timestamp('2110-11-16 18:07:00'),
#   'LOS': 0.103,
#   'ADMITTIME': '16-11-2110 15:32',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 456,
#   'HADM_ID': 113035,
#   'ICUSTAY_ID': 212654,
#   'INTIME': Timestamp('2197-11-16 13:52:00'),
#   'OUTTIME': Timestamp('2197-11-18 16:19:00'),
#   'LOS': 2.1021,
#   'ADMITTIME': '16-11-2197 12:22',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'CARDIAC ARREST\\CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 457,
#   'HADM_ID': 166305,
#   'ICUSTAY_ID': 278242,
#   'INTIME': Timestamp('2146-01-30 22:54:00'),
#   'OUTTIME': Timestamp('2146-02-23 12:43:00'),
#   'LOS': 23.5759,
#   'ADMITTIME': '30-01-2146 17:54',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'MENTAL STUATUS CHANGE RULE-OUT EPIDURAL ABCESS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 458,
#   'HADM_ID': 183288,
#   'ICUSTAY_ID': 279940,
#   'INTIME': Timestamp('2152-01-22 18:26:00'),
#   'OUTTIME': Timestamp('2152-01-24 17:36:00'),
#   'LOS': 1.9651,
#   'ADMITTIME': '22-01-2152 18:24',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicaid',
#   'LANGUAGE': 'RUSS',
#   'RELIGION': 'OTHER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'SEIZURE',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 459,
#   'HADM_ID': 117775,
#   'ICUSTAY_ID': 201950,
#   'INTIME': Timestamp('2199-03-04 15:39:00'),
#   'OUTTIME': Timestamp('2199-03-04 17:45:00'),
#   'LOS': 0.0878,
#   'ADMITTIME': '04-03-2199 13:28',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'BLACK/AFRICAN AMERICAN',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 460,
#   'HADM_ID': 145034,
#   'ICUSTAY_ID': 232390,
#   'INTIME': Timestamp('2117-05-28 01:50:00'),
#   'OUTTIME': Timestamp('2117-05-30 14:09:00'),
#   'LOS': 2.5128,
#   'ADMITTIME': '25-05-2117 08:41',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 461,
#   'HADM_ID': 185084,
#   'ICUSTAY_ID': 225879,
#   'INTIME': Timestamp('2122-01-11 07:23:00'),
#   'OUTTIME': Timestamp('2122-01-13 13:19:00'),
#   'LOS': 2.2473,
#   'ADMITTIME': '09-01-2122 13:23',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'OTHER',
#   'DIAGNOSIS': 'RECURRENT PLEURAL EFFUSION\\PLEUROSCOPY/CHEST TUBE PLACEMENT',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 462,
#   'HADM_ID': 115006,
#   'ICUSTAY_ID': 284942,
#   'INTIME': Timestamp('2131-05-25 15:49:00'),
#   'OUTTIME': Timestamp('2131-05-28 09:50:00'),
#   'LOS': 2.7507,
#   'ADMITTIME': '25-05-2131 12:09',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'OTHER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'ACUTE MYOCARDIAL INFARCTION\\CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 463,
#   'HADM_ID': 197296,
#   'ICUSTAY_ID': 222466,
#   'INTIME': Timestamp('2198-10-05 16:44:00'),
#   'OUTTIME': Timestamp('2198-10-07 21:42:00'),
#   'LOS': 2.2073,
#   'ADMITTIME': '05-10-2198 16:43',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'PROTESTANT QUAKER',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'PERICARDIAL EFFUSION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 464,
#   'HADM_ID': 194697,
#   'ICUSTAY_ID': 272880,
#   'INTIME': Timestamp('2171-04-18 12:44:00'),
#   'OUTTIME': Timestamp('2171-04-19 20:14:00'),
#   'LOS': 1.3127,
#   'ADMITTIME': '18-04-2171 12:43',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'NOT SPECIFIED',
#   'MARITAL_STATUS': 'SINGLE',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'DIABETIC KETOACIDOSIS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 465,
#   'HADM_ID': 128658,
#   'ICUSTAY_ID': 220413,
#   'INTIME': Timestamp('2127-08-13 17:45:00'),
#   'OUTTIME': Timestamp('2127-08-26 09:54:00'),
#   'LOS': 12.6728,
#   'ADMITTIME': '13-08-2127 17:42',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 466,
#   'HADM_ID': 150423,
#   'ICUSTAY_ID': 225985,
#   'INTIME': Timestamp('2173-01-31 08:56:00'),
#   'OUTTIME': Timestamp('2173-02-02 20:33:00'),
#   'LOS': 2.4836,
#   'ADMITTIME': '31-01-2173 08:54',
#   'DEATHTIME': Timestamp('2173-02-09 00:15:00'),
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'JEWISH',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'PNEUMONIA/SEPSIS/RAPID AFIB',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 467,
#   'HADM_ID': 152851,
#   'ICUSTAY_ID': 233617,
#   'INTIME': Timestamp('2199-07-25 08:47:00'),
#   'OUTTIME': Timestamp('2199-07-25 11:24:00'),
#   'LOS': 0.109,
#   'ADMITTIME': '25-07-2199 08:37',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'JEWISH',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 468,
#   'HADM_ID': 109718,
#   'ICUSTAY_ID': 281102,
#   'INTIME': Timestamp('2136-02-24 13:29:00'),
#   'OUTTIME': Timestamp('2136-02-27 17:58:00'),
#   'LOS': 3.1866,
#   'ADMITTIME': '24-02-2136 13:28',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'EMERGENCY ROOM ADMIT',
#   'INSURANCE': 'Private',
#   'LANGUAGE': 'ENGL',
#   'RELIGION': 'OTHER',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'ALTERED MENTAL STATUS',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 469,
#   'HADM_ID': 177871,
#   'ICUSTAY_ID': 217235,
#   'INTIME': Timestamp('2175-04-01 19:19:00'),
#   'OUTTIME': Timestamp('2175-04-07 12:31:00'),
#   'LOS': 5.7167,
#   'ADMITTIME': '01-04-2175 19:08',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 470,
#   'HADM_ID': 188804,
#   'ICUSTAY_ID': 225242,
#   'INTIME': Timestamp('2132-04-01 15:30:00'),
#   'OUTTIME': Timestamp('2132-04-02 11:19:00'),
#   'LOS': 0.8258,
#   'ADMITTIME': '01-04-2132 12:30',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'MARRIED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'CORONARY ARTERY DISEASE\\CORONARY ARTERY BYPASS GRAFT/SDA',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 471,
#   'HADM_ID': 135879,
#   'ICUSTAY_ID': 289189,
#   'INTIME': Timestamp('2122-07-22 14:07:00'),
#   'OUTTIME': Timestamp('2122-07-26 18:31:00'),
#   'LOS': 4.1836,
#   'ADMITTIME': '22-07-2122 14:04',
#   'DEATHTIME': Timestamp('2122-07-30 17:50:00'),
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CHRISTIAN SCIENTIST',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'BRONCIAL CARCINOID, RIGHT MIDDLE LOBE\\BRONCHOSCOPY RIGID; ENDOBRONCHIAL U/S; ? ARAGON PLASMA COAGULATION',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 472,
#   'HADM_ID': 173064,
#   'ICUSTAY_ID': 235215,
#   'INTIME': Timestamp('2172-09-28 19:22:00'),
#   'OUTTIME': Timestamp('2172-10-06 21:27:00'),
#   'LOS': 8.0871,
#   'ADMITTIME': '28-09-2172 19:21',
#   'DEATHTIME': Timestamp('2172-10-06 18:15:00'),
#   'ADMISSION_LOCATION': 'TRANSFER FROM HOSP/EXTRAM',
#   'INSURANCE': 'Medicare',
#   'LANGUAGE': nan,
#   'RELIGION': 'CATHOLIC',
#   'MARITAL_STATUS': 'WIDOWED',
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'NON Q MI\\CATH',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 1},
#  {'SUBJECT_ID': 473,
#   'HADM_ID': 129194,
#   'ICUSTAY_ID': 234500,
#   'INTIME': Timestamp('2201-01-09 20:16:00'),
#   'OUTTIME': Timestamp('2201-02-25 17:54:00'),
#   'LOS': 46.9013,
#   'ADMITTIME': '09-01-2201 20:03',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'CLINIC REFERRAL/PREMATURE',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'UNKNOWN/NOT SPECIFIED',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'M',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  {'SUBJECT_ID': 474,
#   'HADM_ID': 194246,
#   'ICUSTAY_ID': 299250,
#   'INTIME': Timestamp('2181-03-23 08:24:00'),
#   'OUTTIME': Timestamp('2181-03-23 11:09:00'),
#   'LOS': 0.1148,
#   'ADMITTIME': '23-03-2181 08:11',
#   'DEATHTIME': NaT,
#   'ADMISSION_LOCATION': 'PHYS REFERRAL/NORMAL DELI',
#   'INSURANCE': 'Private',
#   'LANGUAGE': nan,
#   'RELIGION': 'UNOBTAINABLE',
#   'MARITAL_STATUS': nan,
#   'ETHNICITY': 'WHITE',
#   'DIAGNOSIS': 'NEWBORN',
#   'HAS_CHARTEVENTS_DATA': 1,
#   'GENDER': 'F',
#   'CHARTEVENTS': [],
#   'LABEL': 0},
#  ...]

# %%
# jgc

# %%
logging.info("read chart events in chunks form and append chart events to matching icu stay id (3hrs from in_time)")
chunk_size=10000000
chart_events_path=r'D:\FINALYEARPROJECTREC\data\CHARTEVENTS.csv'
with pd.read_csv(chart_events_path, usecols=chart_events_keys, parse_dates=chart_events_dates, chunksize=chunk_size) as reader:
    count=0
    for chunk in reader:
        s=datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        # convert null to None (valuenum)
        # chunk = chunk.replace({np.nan: None})
        # eliminate nan value_nums in CHARTEVENTS.csv
        chunk = chunk[chunk['VALUENUM'].notna()]
        print(chunk.head())
        # logging.info(" create 'ITEMID', 'VALUENUM', 'CHARTTIME' of each row as single list, and add into new column 'CHARTEVENTS'")
        chunk['CHARTEVENTS'] = chunk[chunk.columns[1:]].apply(lambda x: list(x), axis=1)
        # drop previous 'ITEMID', 'VALUENUM', 'CHARTTIME' columns
        chunk.drop(['ITEMID', 'CHARTTIME', 'VALUENUM'], axis=1, inplace=True)
        # group chunk dataframe by ICUSTAY_ID, and concat all chart events data into single list
        chunk = chunk.groupby('ICUSTAY_ID')['CHARTEVENTS'].apply(list).reset_index(name='CHARTEVENTS')
        # convert dataframe to dictionary format
        chunk_dict = chunk.to_dict('records')
    
    # for each ICUSTAY_ID in chart events chunk
        for i in chunk_dict:
            icu_id = i['ICUSTAY_ID']
            r = 0
            # loop through icu stays dataframe
            for j in icu_adm_dict:
                # if match exists between chunk ICUSTAY_ID and icu stays dataframe ICUSTAY_ID
                if j['ICUSTAY_ID'] == icu_id:
                    # if chart events of icu stay is equal to 100, break
                    if len(j['CHARTEVENTS']) == 100:
                        r += 1
                        break

                    # access in time of icu stay
                    in_time = j['INTIME']

                    # for each chunk CHARTEVENTS data
                    for k in i['CHARTEVENTS']:
                        # if chart event time is within 3 hours after in time
                        if (k[1] >= in_time) & ((k[1] - in_time)/np.timedelta64(1, 'h') <= 3):
                            # modify timestamp to (chart event time - in time) in minutes
                            k[1] = (k[1] - in_time)/np.timedelta64(1, 'm')
                            # append icu stays dataframe CHARTEVENTS list with chunk CHARTEVENTS data
                            # order: timestamp, item_id, value_num
                            j['CHARTEVENTS'].append([k[1], k[0], k[2]])
                        # if chart events of icu stay length is equal to 100, break
                        if len(j['CHARTEVENTS']) == 100:
                            r += 1
                            break

        s = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        print("[", s, "] FINISHED READING CHARTEVENTS CHUNK ", count)
        count += 1
# Out:
#    ICUSTAY_ID  ITEMID           CHARTTIME  VALUENUM
# 0    241249.0  223834 2134-05-12 12:00:00     15.00
# 1    241249.0  223835 2134-05-12 12:00:00    100.00
# 2    241249.0  224328 2134-05-12 12:00:00      0.37
# 3    241249.0  224329 2134-05-12 12:00:00      6.00
# 4    241249.0  224330 2134-05-12 12:00:00      2.50
# [ 2025-02-28 16:14:17 ] FINISHED READING CHARTEVENTS CHUNK  0
#           ICUSTAY_ID  ITEMID           CHARTTIME  VALUENUM
# 10000000    246813.0  220052 2186-10-14 03:57:00      80.0
# 10000001    246813.0  220074 2186-10-14 03:57:00      15.0
# 10000002    246813.0  220210 2186-10-14 03:57:00      17.0
# 10000003    246813.0  220277 2186-10-14 03:57:00     100.0
# 10000004    246813.0  220292 2186-10-14 03:57:00       4.0

# %%
## save icu stays with chart events to csv file
icu_chart_events = pd.DataFrame.from_records(icu_adm_dict)
print(icu_chart_events.head())
icu_chart_events.to_csv("D:\FINALYEARPROJECTREC\artifacts\icu_with_chart_events_v_not_nan.csv", header=True, index=False)
